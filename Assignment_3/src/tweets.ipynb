# %% [markdown]
# ## TWEETS WORDCLOUD

# %%
#import pandas
import pandas as pd
data=pd.read_csv(r"/Corona_NLP_test.csv",encoding= 'unicode_escape')

# %%
data
# Out:
#       UserName  ScreenName             Location     TweetAt  \
# 0            1       44953                  NYC  02-03-2020
# 1            2       44954          Seattle, WA  02-03-2020
# 2            3       44955                  NaN  02-03-2020
# 3            4       44956          Chicagoland  02-03-2020
# 4            5       44957  Melbourne, Victoria  03-03-2020
# ...        ...         ...                  ...         ...
# 3793      3794       48746            Israel ??  16-03-2020
# 3794      3795       48747       Farmington, NM  16-03-2020
# 3795      3796       48748        Haverford, PA  16-03-2020
# 3796      3797       48749                  NaN  16-03-2020
# 3797      3798       48750  Arlington, Virginia  16-03-2020
#
#                                           OriginalTweet           Sentiment
# 0     TRENDING: New Yorkers encounter empty supermar...  Extremely Negative
# 1     When I couldn't find hand sanitizer at Fred Me...            Positive
# ...

# %%
#extract required column
OriginalTweet= data["OriginalTweet"]

# %%
OriginalTweet
# Out:
# 0       TRENDING: New Yorkers encounter empty supermar...
# 1       When I couldn't find hand sanitizer at Fred Me...
# 2       Find out how you can protect yourself and love...
# 3       #Panic buying hits #NewYork City as anxious sh...
# 4       #toiletpaper #dunnypaper #coronavirus #coronav...
#                               ...
# 3793    Meanwhile In A Supermarket in Israel -- People...
# 3794    Did you panic buy a lot of non-perishable item...
# 3795    Asst Prof of Economics @cconces was on @NBCPhi...
# 3796    Gov need to do somethings instead of biar je r...
# 3797    I and @ForestandPaper members are committed to...
# Name: OriginalTweet, Length: 3798, dtype: object

# %%
#write to new csv
data_new=OriginalTweet.to_csv(r"/data_new.csv",index=False)

# %%
data_new=pd.read_csv(r"/data_new.csv",encoding= 'unicode_escape')

# %%
data_new
# Out:
#                                           OriginalTweet
# 0     TRENDING: New Yorkers encounter empty supermar...
# 1     When I couldn't find hand sanitizer at Fred Me...
# 2     Find out how you can protect yourself and love...
# 3     #Panic buying hits #NewYork City as anxious sh...
# 4     #toiletpaper #dunnypaper #coronavirus #coronav...
# ...                                                 ...
# 3793  Meanwhile In A Supermarket in Israel -- People...
# 3794  Did you panic buy a lot of non-perishable item...
# 3795  Asst Prof of Economics @cconces was on @NBCPhi...
# 3796  Gov need to do somethings instead of biar je r...
# 3797  I and @ForestandPaper members are committed to...
#
# [3798 rows x 1 columns]

# %%
data_list=data_new['OriginalTweet'].values.tolist()

# %%
data_list
# Out:
# ['TRENDING: New Yorkers encounter empty supermarket shelves (pictured, Wegmans in Brooklyn), sold-out online grocers (FoodKick, MaxDelivery) as #coronavirus-fearing shoppers stock up https://t.co/Gr76pcrLWh https://t.co/ivMKMsqdT1',
#  "When I couldn't find hand sanitizer at Fred Meyer, I turned to #Amazon. But $114.97 for a 2 pack of Purell??!!Check out how  #coronavirus concerns are driving up prices. https://t.co/ygbipBflMY",
#  'Find out how you can protect yourself and loved ones from #coronavirus. ?',
#  '#Panic buying hits #NewYork City as anxious shoppers stock up on food&amp;medical supplies after #healthcare worker in her 30s becomes #BigApple 1st confirmed #coronavirus patient OR a #Bloomberg staged event?\r\r\n\r\r\nhttps://t.co/IASiReGPC4\r\r\n\r\r\n#QAnon #QAnon2018 #QAnon2020 \r\r\n#Election2020 #CDC https://t.co/29isZOewxu',
# ...

# %% [markdown]
# ## a) Convert the text corpus into tokens.

# %%
pip install nltk

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

# %%
tokens = []
for tweet in data_list:
    tokens += word_tokenize(tweet)
print(tokens)
# Out:
# ['TRENDING', ':', 'New', 'Yorkers', 'encounter', 'empty', 'supermarket', 'shelves', '(', 'pictured', ',', 'Wegmans', 'in', 'Brooklyn', ')', ',', 'sold-out', 'online', 'grocers', '(', 'FoodKick', ',', 'MaxDelivery', ')', 'as', '#', 'coronavirus-fearing', 'shoppers', 'stock', 'up', 'https', ':', '//t.co/Gr76pcrLWh', 'https', ':', '//t.co/ivMKMsqdT1', 'When', 'I', 'could', "n't", 'find', 'hand', 'sanitizer', 'at', 'Fred', 'Meyer', ',', 'I', 'turned', 'to', '#', 'Amazon', '.', 'But', '$', '114.97', 'for', 'a', '2', 'pack', 'of', 'Purell', '?', '?', '!', '!', 'Check', 'out', 'how', '#', 'coronavirus', 'concerns', 'are', 'driving', 'up', 'prices', '.', 'https', ':', '//t.co/ygbipBflMY', 'Find', 'out', 'how', 'you', 'can', 'protect', 'yourself', 'and', 'loved', 'ones', 'from', '#', 'coronavirus', '.', '?', '#', 'Panic', 'buying', 'hits', '#', 'NewYork', 'City', 'as', 'anxious', 'shoppers', 'stock', 'up', 'on', 'food', '&', 'amp', ';', 'medical', 'supplies', 'after', '#', 'healthcare', 'work
# ...

# %% [markdown]
# ## b) Perform stop word removal.

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

#filter
filtered_tokens = [token for token in tokens if not token.lower() in stop_words]
print(filtered_tokens)
# Out:
# ['TRENDING', ':', 'New', 'Yorkers', 'encounter', 'empty', 'supermarket', 'shelves', '(', 'pictured', ',', 'Wegmans', 'Brooklyn', ')', ',', 'sold-out', 'online', 'grocers', '(', 'FoodKick', ',', 'MaxDelivery', ')', '#', 'coronavirus-fearing', 'shoppers', 'stock', 'https', ':', '//t.co/Gr76pcrLWh', 'https', ':', '//t.co/ivMKMsqdT1', 'could', "n't", 'find', 'hand', 'sanitizer', 'Fred', 'Meyer', ',', 'turned', '#', 'Amazon', '.', '$', '114.97', '2', 'pack', 'Purell', '?', '?', '!', '!', 'Check', '#', 'coronavirus', 'concerns', 'driving', 'prices', '.', 'https', ':', '//t.co/ygbipBflMY', 'Find', 'protect', 'loved', 'ones', '#', 'coronavirus', '.', '?', '#', 'Panic', 'buying', 'hits', '#', 'NewYork', 'City', 'anxious', 'shoppers', 'stock', 'food', '&', 'amp', ';', 'medical', 'supplies', '#', 'healthcare', 'worker', '30s', 'becomes', '#', 'BigApple', '1st', 'confirmed', '#', 'coronavirus', 'patient', '#', 'Bloomberg', 'staged', 'event', '?', 'https', ':', '//t.co/IASiReGPC4', '#', 'QAnon', 
# ...

# %% [markdown]
# ## using regural expressions to remove special charecters

# %%
import re
normal_string=re.sub("[^a-zA-Z' ']",' ', " ".join(filtered_tokens))

# %%
normal_string
# Out:
# "TRENDING   New Yorkers encounter empty supermarket shelves   pictured   Wegmans Brooklyn     sold out online grocers   FoodKick   MaxDelivery     coronavirus fearing shoppers stock https     t co Gr  pcrLWh https     t co ivMKMsqdT  could n't find hand sanitizer Fred Meyer   turned   Amazon              pack Purell         Check   coronavirus concerns driving prices   https     t co ygbipBflMY Find protect loved ones   coronavirus       Panic buying hits   NewYork City anxious shoppers stock food   amp   medical supplies   healthcare worker   s becomes   BigApple  st confirmed   coronavirus patient   Bloomberg staged event   https     t co IASiReGPC    QAnon   QAnon       QAnon       Election       CDC https     t co   isZOewxu   toiletpaper   dunnypaper   coronavirus   coronavirusaustralia   CoronaVirusUpdate   Covid       News   Corvid      NewsMelb   dunnypapergate   Costco One week everyone buying baby milk powder next everyone buying toilet paper   https     t co ScZryVvsIh rem
# ...

# %%
list_new=normal_string.split(" ")
type(list_new)
# Out:
# list

# %%
list_new
# Out:
# ['TRENDING',
#  '',
#  '',
#  'New',
#  'Yorkers',
#  'encounter',
#  'empty',
#  'supermarket',
#  'shelves',
#  '',
#  '',
#  'pictured',
#  '',
#  '',
#  'Wegmans',
#  'Brooklyn',
#  '',
#  '',
#  '',
#  '',
#  'sold',
#  'out',
#  'online',
#  'grocers',
#  '',
#  '',
#  'FoodKick',
#  '',
#  '',
#  'MaxDelivery',
#  '',
#  '',
#  '',
#  '',
#  'coronavirus',
#  'fearing',
#  'shoppers',
#  'stock',
#  'https',
#  '',
#  '',
#  '',
#  '',
#  't',
#  'co',
#  'Gr',
#  '',
#  'pcrLWh',
#  'https',
#  '',
#  '',
#  '',
#  '',
#  't',
#  'co',
#  'ivMKMsqdT',
#  '',
#  'could',
#  "n't",
#  'find',
#  'hand',
#  'sanitizer',
#  'Fred',
#  'Meyer',
#  '',
#  '',
#  'turned',
#  '',
#  '',
#  'Amazon',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'pack',
#  'Purell',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Check',
#  '',
#  '',
#  'coronavirus',
#  'concerns',
#  'driving',
#  'prices',
#  '',
#  '',
#  'https',
# ...

# %%
#remove_space
delete_empty = [ele for ele in list_new if ele.strip()]
delete_empty
# Out:
# ['TRENDING',
#  'New',
#  'Yorkers',
#  'encounter',
#  'empty',
#  'supermarket',
#  'shelves',
#  'pictured',
#  'Wegmans',
#  'Brooklyn',
#  'sold',
#  'out',
#  'online',
#  'grocers',
#  'FoodKick',
#  'MaxDelivery',
#  'coronavirus',
#  'fearing',
#  'shoppers',
#  'stock',
#  'https',
#  't',
#  'co',
#  'Gr',
#  'pcrLWh',
#  'https',
#  't',
#  'co',
#  'ivMKMsqdT',
#  'could',
#  "n't",
#  'find',
#  'hand',
#  'sanitizer',
#  'Fred',
#  'Meyer',
#  'turned',
#  'Amazon',
#  'pack',
#  'Purell',
#  'Check',
#  'coronavirus',
#  'concerns',
#  'driving',
#  'prices',
#  'https',
#  't',
#  'co',
#  'ygbipBflMY',
#  'Find',
#  'protect',
#  'loved',
#  'ones',
#  'coronavirus',
#  'Panic',
#  'buying',
#  'hits',
#  'NewYork',
#  'City',
#  'anxious',
#  'shoppers',
#  'stock',
#  'food',
#  'amp',
#  'medical',
#  'supplies',
#  'healthcare',
#  'worker',
#  's',
#  'becomes',
#  'BigApple',
#  'st',
#  'confirmed',
#  'coronavirus',
#  'patient',
#  'Bloomberg',
# ...

# %% [markdown]
# ## c) Count Word frequencies

# %%
from collections import Counter

# Count the word frequencies
word_freq = dict(Counter(delete_empty))
print(word_freq)
# Out:
# {'TRENDING': 1, 'New': 25, 'Yorkers': 3, 'encounter': 3, 'empty': 123, 'supermarket': 468, 'shelves': 203, 'pictured': 1, 'Wegmans': 5, 'Brooklyn': 5, 'sold': 30, 'out': 15, 'online': 457, 'grocers': 6, 'FoodKick': 1, 'MaxDelivery': 1, 'coronavirus': 1202, 'fearing': 1, 'shoppers': 36, 'stock': 693, 'https': 1825, 't': 2220, 'co': 1831, 'Gr': 1, 'pcrLWh': 1, 'ivMKMsqdT': 1, 'could': 85, "n't": 344, 'find': 54, 'hand': 129, 'sanitizer': 82, 'Fred': 2, 'Meyer': 2, 'turned': 4, 'Amazon': 57, 'pack': 12, 'Purell': 1, 'Check': 18, 'concerns': 18, 'driving': 8, 'prices': 410, 'ygbipBflMY': 1, 'Find': 4, 'protect': 30, 'loved': 5, 'ones': 21, 'Panic': 47, 'buying': 296, 'hits': 5, 'NewYork': 4, 'City': 14, 'anxious': 7, 'food': 1240, 'amp': 610, 'medical': 27, 'supplies': 165, 'healthcare': 26, 'worker': 14, 's': 345, 'becomes': 4, 'BigApple': 1, 'st': 11, 'confirmed': 20, 'patient': 9, 'Bloomberg': 1, 'staged': 1, 'event': 12, 'IASiReGPC': 1, 'QAnon': 4, 'Election': 2, 'CDC': 15, 'isZOewxu
# ...

# %%
len(word_freq)
type(word_freq)
#(word_freq)
# Out:
# dict

# %%
len(word_freq)
# Out:
# 16741

# %%
word_freq
# Out:
# {'TRENDING': 1,
#  'New': 25,
#  'Yorkers': 3,
#  'encounter': 3,
#  'empty': 123,
#  'supermarket': 468,
#  'shelves': 203,
#  'pictured': 1,
#  'Wegmans': 5,
#  'Brooklyn': 5,
#  'sold': 30,
#  'out': 15,
#  'online': 457,
#  'grocers': 6,
#  'FoodKick': 1,
#  'MaxDelivery': 1,
#  'coronavirus': 1202,
#  'fearing': 1,
#  'shoppers': 36,
#  'stock': 693,
#  'https': 1825,
#  't': 2220,
#  'co': 1831,
#  'Gr': 1,
#  'pcrLWh': 1,
#  'ivMKMsqdT': 1,
#  'could': 85,
#  "n't": 344,
#  'find': 54,
#  'hand': 129,
#  'sanitizer': 82,
#  'Fred': 2,
#  'Meyer': 2,
#  'turned': 4,
#  'Amazon': 57,
#  'pack': 12,
#  'Purell': 1,
#  'Check': 18,
#  'concerns': 18,
#  'driving': 8,
#  'prices': 410,
#  'ygbipBflMY': 1,
#  'Find': 4,
#  'protect': 30,
#  'loved': 5,
#  'ones': 21,
#  'Panic': 47,
#  'buying': 296,
#  'hits': 5,
#  'NewYork': 4,
#  'City': 14,
#  'anxious': 7,
#  'food': 1240,
#  'amp': 610,
#  'medical': 27,
#  'supplies': 165,
#  'healthcare': 26,
#  'worker': 14,
#  's': 345,
# ...

# %%
d = dict((k, v) for k, v in word_freq.items() if v >= 100)
d
len(d)
# Out:
# 82

# %% [markdown]
# ## d) Create word clouds.

# %%
all_words = ' '.join(delete_empty)

from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()
